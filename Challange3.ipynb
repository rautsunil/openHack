# %%
from __future__ import division
from __future__ import print_function
from PIL import Image
import sys
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from io import BytesIO
from sklearn.metrics import accuracy_score
import urllib.request as urllib2
from urllib.parse import urlparse

# %%
clf = RandomForestClassifier()

def process_image_url(image_url):
    '''Given an image URL it returns its feature vector

    Args:
      image_url (str): url of the image to process.

    Returns:
      list of float: feature vector.

    Raises:
      Any exception raised by urllib2 requests.

      IOError: if the URL does not point to a valid file.
    '''
    parsed_url = urlparse(image_url)
    request = urllib2.Request(image_url)
    # set a User-Agent and Referer to work around servers that block a typical
    # user agents and hotlinking. Sorry, it's for science!
    request.add_header('User-Agent', 'Mozilla/5.0 (X11; Ubuntu; Linux ' \
            'x86_64; rv:31.0) Gecko/20100101 Firefox/31.0')
    request.add_header('Referrer', parsed_url.netloc)
    # Wrap network data in StringIO so that it looks like a file
    net_data = BytesIO(urllib2.build_opener().open(request).read())
    image = Image.open(net_data)
    return process_image(image)


def process_image(image, blocks=4):
    '''Given a PIL Image object it returns its feature vector.

    Args:
      image (PIL.Image): image to process.
      blocks (int, optional): number of block to subdivide the RGB space into.

    Returns:
      list of float: feature vector if successful. None if the image is not
      RGB.
    '''
    if not image.mode == 'RGB':
        return None
    feature = [0] * blocks * blocks * blocks
    pixel_count = 0
    for pixel in image.getdata():
        ridx = int(pixel[0]/(256/blocks))
        gidx = int(pixel[1]/(256/blocks))
        bidx = int(pixel[2]/(256/blocks))
        idx = ridx + gidx * blocks + bidx * blocks * blocks
        feature[idx] += 1
        pixel_count += 1
        
    return [x/pixel_count for x in feature]

def process_image_file(image_path):
    '''Given an image path it returns its feature vector.

    Args:
      image_path (str): path of the image file to process.

    Returns:
      list of float: feature vector on success, None otherwise.
    '''
    image_fp = BytesIO(open(image_path, 'rb').read())
    try:
        image = Image.open(image_fp)
        return process_image(image)
    except IOError:
        print("Exception" , IoError)
        return None
    
def process_directory(directory):
    '''Returns an array of feature vectors for all the image files in a
    directory (and all its subdirectories). Symbolic links are ignored.

    Args:
      directory (str): directory to process.

    Returns:
      list of list of float: a list of feature vectors.
    '''
    training = []
    for root, _, files in os.walk(directory):
        for file_name in files:
            file_path = os.path.join(root, file_name)
            img_feature = process_image_file(file_path)
            print(file_path)
            if img_feature:
                training.append(img_feature)
    return training

# %%
def train(training_path_a,training_path_b):
    print("Hello")
    training_a = process_directory(training_path_a)
    training_b = process_directory(training_path_b)
    data = training_a + training_b
    # target is the list of target classes for each feature vector: a '1' for
    # class A and '0' for class B
    target = [1] * len(training_a) + [0] * len(training_b)
    x_train, x_test, y_train, y_test = train_test_split(data,
            target, test_size=0.20)
    clf.fit(x_train, y_train)
    preds = clf.predict(x_test)

    print("Accuracy:", accuracy_score(y_test,preds))

# %%
train("gear_images/helmets","gear_images/boots")
# Out:
# Hello
# gear_images/helmets/100536.jpeg
# gear_images/helmets/10085954x1031041_zm.jpeg
# gear_images/helmets/10085954x1114172_zm.jpeg
# gear_images/helmets/10085954x1114180_zm.jpeg
# gear_images/helmets/10085954x1114185_zm.jpeg
# gear_images/helmets/10093454x1013457_zm.jpeg
# gear_images/helmets/10093454x1042156_zm.jpeg
# gear_images/helmets/100943.jpeg
# gear_images/helmets/100973.jpeg
# gear_images/helmets/10187948x1011898_zm.jpeg
# gear_images/helmets/10187948x1012905_zm.jpeg
# gear_images/helmets/10187948x1046104_zm.jpeg
# gear_images/helmets/10187948x1078795_zm.jpeg
# gear_images/helmets/10187949x1040578_zm.jpeg
# gear_images/helmets/10187949x1121031_zm.jpeg
# gear_images/helmets/10188393x1011898_zm.jpeg
# gear_images/helmets/10188393x1043709_zm.jpeg
# gear_images/helmets/10188393x1105548_zm.jpeg
# gear_images/helmets/10188394x1011898_zm.jpeg
# gear_images/helmets/10188395x1036824_zm.jpeg
# gear_images/helmets/10190075x1102897_zm.jpeg
# gear_images/helmets/10190075x1145821_zm.jpeg
# gear_images/helmets/10190104x1010868_zm.jpeg
# gear_images/helmets/10190104x1011898_zm.jpeg
# gear_images/helmets/10190104x1012549_zm.jpeg
# gear_images/helmets/10190104x1012905_zm.jpeg
# gear_images/helmets/10208341x1011834_zm.jpeg
# gear_images/helmets/10208341x1046104_zm.jpeg
# gear_images/helmets/10208341x1046806_zm.jpeg
# gear_images/helmets/10208341x1062229_zm.jpeg
# gear_images/helmets/10216108x1011898_zm.jpeg
# gear_images/helmets/10225848x1010938_zm.jpeg
# gear_images/helmets/10225848x1037246_zm.jpeg
# gear_images/helmets/10239792x1052090_zm.jpeg
# gear_images/helmets/10239792x1145773_zm.jpeg
# gear_images/helmets/10253748x1010868_zm.jpeg
# gear_images/helmets/10274402x1010868_zm.jpeg
# gear_images/helmets/10274402x1011898_zm.jpeg
# gear_images/helmets/10308340x1001992_zm.jpeg
# gear_images/helmets/10308340x1011898_zm.jpeg
# gear_images/helmets/10308340x1027215_zm.jpeg
# gear_images/helmets/10308590x1010868_zm.jpeg
# gear_images/helmets/10308590x1010913_zm.jpeg
# gear_images/helmets/10308590x1012163_zm.jpeg
# gear_images/helmets/10308590x1013039_zm.jpeg
# gear_images/helmets/10311144x1010868_zm.jpeg
# gear_images/helmets/10311144x1010913_zm.jpeg
# gear_images/helmets/10311144x1013039_zm.jpeg
# gear_images/helmets/10311145x1003070_zm.jpeg
# gear_images/helmets/10311145x1010868_zm.jpeg
# gear_images/helmets/10311145x1012549_zm.jpeg
# gear_images/helmets/10311145x1013039_zm.jpeg
# gear_images/helmets/10311154x1011898_zm.jpeg
# gear_images/helmets/10311154x1012346_zm.jpeg
# gear_images/helmets/10311154x1012549_zm.jpeg
# gear_images/helmets/10311543x1010868_zm.jpeg
# gear_images/helmets/10311543x1011898_zm.jpeg
# gear_images/helmets/10311543x1012549_zm.jpeg
# gear_images/helmets/10311543x1013039_zm.jpeg
# gear_images/helmets/10311543x1128005_zm.jpeg
# gear_images/helmets/10337586x1010868_zm.jpeg
# gear_images/helmets/10337586x1010913_zm.jpeg
# gear_images/helmets/10337586x1012549_zm.jpeg
# gear_images/helmets/10339623_zm.jpeg
# gear_images/helmets/10353621x1012905_zm.jpeg
# gear_images/helmets/10373906x1011898_zm.jpeg
# gear_images/helmets/10373906x1012549_zm.jpeg
# gear_images/helmets/10373906x1037650_zm.jpeg
# gear_images/helmets/110031.jpeg
# gear_images/helmets/114688.png
# gear_images/helmets/114689.png
# gear_images/helmets/114692.png
# gear_images/helmets/125475.jpeg
# gear_images/helmets/125476.jpeg
# gear_images/helmets/1313675_801_main.png
# gear_images/helmets/1313681_801_main.png
# gear_images/helmets/2039611_101_main.jpg
# gear_images/helmets/2039613_408_main.jpg
# gear_images/helmets/2039617_004_main.jpg
# gear_images/helmets/2039626_004_main.jpg
# gear_images/helmets/2039658_408_main.jpg
# gear_images/helmets/2039689_101_main.jpg
# gear_images/helmets/831117.jpeg
# gear_images/helmets/831150.jpeg
# gear_images/helmets/850336.jpeg
# gear_images/helmets/882318.jpeg
# gear_images/helmets/897876.jpeg
# gear_images/helmets/899118.jpeg
# gear_images/helmets/899119.jpeg
# gear_images/helmets/899120.jpeg
# gear_images/helmets/PMMPIHOEHODFMANJx1038115_zm.jpeg
# gear_images/helmets/PMMPIHOEHODFMANJx1046104_zm.jpeg
# gear_images/helmets/PMMPIHOEHODFMANJx1078795_zm.jpeg
# gear_images/helmets/PMMPIHOEHODFMANJx1093407_zm.jpeg
# gear_images/helmets/PMMPIHOEHODFMANJx1121032_zm.jpeg
# gear_images/boots/10018755x1036824_zm.jpeg
# gear_images/boots/10025602x1037016_zm.jpeg
# gear_images/boots/10025823x1060557_zm.jpeg
# gear_images/boots/10084984x1012905_zm.jpeg
# gear_images/boots/10101265x1011117_zm.jpeg
# gear_images/boots/10170757x1014040_zm.jpeg
# gear_images/boots/10200679x1011850_zm.jpeg
# gear_images/boots/10200698x1011850_zm.jpeg
# gear_images/boots/10211759x1104651_zm.jpeg
# gear_images/boots/10216475x1043345_zm.jpeg
# gear_images/boots/10219722x1041642_zm.jpeg
# gear_images/boots/10219749x1060653_zm.jpeg
# gear_images/boots/10240274x1036930_zm.jpeg
# gear_images/boots/10240275x1036930_zm.jpeg
# gear_images/boots/10240279x1036930_zm.jpeg
# gear_images/boots/10241341x1036951_zm.jpeg
# gear_images/boots/10241341x1052351_zm.jpeg
# gear_images/boots/10243530x1037016_zm.jpeg
# gear_images/boots/10243572x1043971_zm.jpeg
# gear_images/boots/10255616x1011898_zm.jpeg
# gear_images/boots/10255621x1039826_zm.jpeg
# gear_images/boots/10270446x1103408_zm.jpeg
# gear_images/boots/10270695x1051081_zm.jpeg
# gear_images/boots/10290794x1011441_zm.jpeg
# gear_images/boots/10296921x1118332_zm.jpeg
# gear_images/boots/10300048x1101054_zm.jpeg
# gear_images/boots/10303016x1052599_zm.jpeg
# gear_images/boots/10304046x1122871_zm.jpeg
# gear_images/boots/10304622x1123061_zm.jpeg
# gear_images/boots/10305295x1039826_zm.jpeg
# gear_images/boots/10305296x1039826_zm.jpeg
# gear_images/boots/10306541x1013052_zm.jpeg
# gear_images/boots/10323078x1042840_zm.jpeg
# gear_images/boots/10323079x1040337_zm.jpeg
# gear_images/boots/10323515x1012905_zm.jpeg
# gear_images/boots/10326416x1013041_zm.jpeg
# gear_images/boots/10326417x1012905_zm.jpeg
# gear_images/boots/10331425x1011760_zm.jpeg
# gear_images/boots/10331427x1141592_zm.jpeg
# gear_images/boots/10331428x1012948_zm.jpeg
# gear_images/boots/10334266x1143977_zm.jpeg
# gear_images/boots/10334401x1144029_zm.jpeg
# gear_images/boots/10334412x1087698_zm.jpeg
# gear_images/boots/10334413x1144029_zm.jpeg
# gear_images/boots/10334414x1144030_zm.jpeg
# gear_images/boots/10345908x1010938_zm.jpeg
# gear_images/boots/10345928x1037092_zm.jpeg
# gear_images/boots/10345929x1037092_zm.jpeg
# gear_images/boots/10345941x1010913_zm.jpeg
# gear_images/boots/10345947x1013041_zm.jpeg
# gear_images/boots/10345977x1037092_zm.jpeg
# gear_images/boots/105262.jpeg
# gear_images/boots/113101.jpeg
# gear_images/boots/113106.jpeg
# gear_images/boots/113107.jpeg
# gear_images/boots/113122.jpeg
# gear_images/boots/113526.jpeg
# gear_images/boots/113528.jpeg
# gear_images/boots/41edw+BCUjL._AC_US436_QL65_.jpg
# gear_images/boots/41g8AEsxLvL._AC_US436_QL65_.jpg
# gear_images/boots/41KnC3aFGUL._AC_US436_QL65_.jpg
# gear_images/boots/41pNuZSfz+L._AC_US436_QL65_.jpg
# gear_images/boots/41PwYvq6hGL._AC_US436_QL65_.jpg
# gear_images/boots/41xDIHr+AeL._AC_US436_QL65_.jpg
# gear_images/boots/51+nIOMqb8L._AC_US436_QL65_.jpg
# gear_images/boots/51+sBEj9KQL._AC_US436_QL65_.jpg
# gear_images/boots/512h+0ULvzL._AC_US436_QL65_.jpg
# gear_images/boots/515b5yc46SL._AC_US436_QL65_.jpg
# gear_images/boots/516q5-A0wJL._AC_US436_QL65_.jpg
# gear_images/boots/517uO6dTZwL._AC_US436_QL65_.jpg
# gear_images/boots/51AgGxRzlxL._AC_US436_QL65_.jpg
# gear_images/boots/51b3fV1+VnL._AC_US436_QL65_.jpg
# gear_images/boots/51Bmk2vA-1L._AC_US436_QL65_.jpg
# gear_images/boots/51DbnWtlxIL._AC_US436_QL65_.jpg
# gear_images/boots/51dy1tmscGL._AC_US436_QL65_.jpg
# gear_images/boots/51fxSrdRH3L._AC_US436_QL65_.jpg
# gear_images/boots/51fzUBASxyL._AC_US436_QL65_.jpg
# gear_images/boots/51hAX8xT6bL._AC_US436_QL65_.jpg
# gear_images/boots/51hgB3uDubL._AC_US436_QL65_.jpg
# gear_images/boots/51HtbaNyWrL._AC_US436_QL65_.jpg
# gear_images/boots/51ibQtw+VfL._AC_US436_QL65_.jpg
# gear_images/boots/51IJ--8cbyL._AC_US436_QL65_.jpg
# gear_images/boots/51IyupjqF-L._AC_US436_QL65_.jpg
# gear_images/boots/51J1tNBAB2L._AC_US436_QL65_.jpg
# gear_images/boots/51KeZRFZ0oL._AC_US436_QL65_.jpg
# gear_images/boots/51KhQXD6tIL._AC_US436_QL65_.jpg
# gear_images/boots/51LiOiGtpLL._AC_US436_QL65_.jpg
# gear_images/boots/51LnXV8cqtL._AC_US436_QL65_.jpg
# gear_images/boots/51mDm6rlLcL._AC_US436_QL65_.jpg
# gear_images/boots/51MiCLo7tEL._AC_US436_QL65_.jpg
# gear_images/boots/51nFShTzUFL._AC_US436_QL65_.jpg
# gear_images/boots/51q6csZ+HwL._AC_US436_QL65_.jpg
# gear_images/boots/51QgEWGyZ-L._AC_US436_QL65_.jpg
# gear_images/boots/51t-mAcoA0L._AC_US436_QL65_.jpg
# gear_images/boots/51VGqNBvazL._AC_US436_QL65_.jpg
# gear_images/boots/51WX8V6q94L._AC_US436_QL65_.jpg
# gear_images/boots/51xk7ZHkCkL._AC_US436_QL65_.jpg
# gear_images/boots/51XZd2kVbfL._AC_US436_QL65_.jpg
# gear_images/boots/51y2T-wFPqL._AC_US436_QL65_.jpg
# gear_images/boots/51yQeovtEdL._AC_US436_QL65_.jpg
# gear_images/boots/51YZs+KEHML._AC_US436_QL65_.jpg
# gear_images/boots/51ZAghEeYGL._AC_US436_QL65_.jpg
# gear_images/boots/733952.jpeg
# gear_images/boots/859910.jpeg
# gear_images/boots/866158.jpeg
# gear_images/boots/866908.jpeg
# gear_images/boots/866950.jpeg
# gear_images/boots/866951.jpeg
# gear_images/boots/874196.jpeg
# gear_images/boots/881270.jpeg
# gear_images/boots/881431.jpeg
# gear_images/boots/896259.jpeg
# gear_images/boots/896260.jpeg
# gear_images/boots/PAAAIAHENGMMFJBAx1002668_zm.jpeg
# gear_images/boots/PAAAIALEPOLAOKBAx1039826_zm.jpeg
# gear_images/boots/PMMPIHLHKKCNMANJx1014040_zm.jpeg
# Accuracy: 0.8095238095238095

# %%
from sklearn.metrics import accuracy_score
preds = clf.predict(x_test)

print("Accuracy:", accuracy_score(y_test,preds))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-c2cda9cfc902> in <module>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 preds = clf.predict(x_test)
#       3
#       4 print("Accuracy:", accuracy_score(y_test,preds))
#
# NameError: name 'x_test' is not defined

# %%
#test my classifier
X = process_image_url("https://shop.epictv.com/sites/default/files/ae42ad29e70ba8ce6b67d3bdb6ab5c6e.jpeg")
X = X.reshape(X.shape[0]*X.shape[1]*X.shape[2],X.shape[3]).T
y = Y.reshape(y.shape[0],)
X, y = shuffle(X, y, random_state=42)
print(clf.predict(features))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-941bb43ba7af> in <module>()
#       1 #test my classifier
#       2 X = process_image_url("https://shop.epictv.com/sites/default/files/ae42ad29e70ba8ce6b67d3bdb6ab5c6e.jpeg")
# ----> 3 X = X.reshape(X.shape[0]*X.shape[1]*X.shape[2],X.shape[3]).T
#       4 y = Y.reshape(y.shape[0],)
#       5 X, y = shuffle(X, y, random_state=42)
#
# AttributeError: 'list' object has no attribute 'reshape'
